# %%
# Imports
import os
from groq import Groq
import time
from groq import InternalServerError
import json
import jinja2
import datetime
from openai import OpenAI

# %% [markdown]
# Here we have:
# - paths to the prompt template and the annotation files folder
#
#
# - the list of types of prompts (zero-shot, one-shot, few-shot)
#
#
# - the list of models tested
#
#
# - the list of entities in which we are interested in
#
# **MODIFY THE LIST OF PROMPTS AND MODELS TO YOUR LIKING**

# %%
# Folder with the ground-truth texts
ANNOTATIONS_FOLDER = "../annotations/"

# Folder with the prompt templates
PROMPT_PATH = "../prompt_templates/"

# List of prompt templates
LIST_PROMPTS = [
    "zero_shot",
    "one_shot",
    "few_shot"
]

# List of models to test
LIST_MODELS_GROQ = [
    "gemma2-9b-it",
    "mistral-saba-24b",
    "llama-3.3-70b-versatile",
    "qwen-qwq-32b",
    "meta-llama/llama-4-maverick-17b-128e-instruct",
    "deepseek-r1-distill-llama-70b"
    # "deepseek-r1-distill-qwen-32b" # has been decommissioned
    ]

LIST_MODELS_OPENAI = [
    "gpt-4.1-2025-04-14",
    # "gpt-4o-2024-11-20",
    #"o3-2025-04-16"
]

# List of entities to tag (by the llms) and then extract
TAGS = ["MOL", "SOFTNAME", "SOFTVERS", "STIME", "TEMP", "FFM"]

API_TYPE = "groq"

NUMBER_OF_TEXTS_TO_ANNOTATE = 100

# %% [markdown]
# # **Prompt engineering with LLMs**
# ---
#
# Currently in this notebook, we have tested only models using the Groq API.
# Models from using the OpenAI API will be added soon.

# %%
# Choose which API to use
def get_api(api_type: str) -> object:
    if api_type == "openai":
        return OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
    elif api_type == "groq":
        return Groq(api_key=os.environ.get("GROQ_API_KEY"))
    else:
        raise ValueError("Invalid API type. Choose 'openai' or 'groq'.")

# %%
# Set up the environment variable for the API key
client = get_api(API_TYPE)

# %% [markdown]
# Firstly, we need a helper function to extract certain information from the ground-truth data:
# - The input text that needs to be annotated (`input_text`)
#
#
# - The manually-found entities (`ground_truth_entities`)

# %%
# Process one JSON file to extract the ground truth entities and the input text
def process_json_file(json_file: str) -> tuple:
    with open(json_file, "r") as f:
        data = json.load(f)

    # Extract the input text
    annotation_entry = data["annotations"][0]
    input_text = annotation_entry[0]
    ground_truth_entities = annotation_entry[1]["entities"]

    return input_text, ground_truth_entities

# %% [markdown]
# Next, we will define several helper functions to assist with the annotation workflow:
#
# 1. **Render the prompt template**
#
#    We use a Jinja2 template to dynamically inject the text that needs to be annotated. This allows for flexible and reusable prompt formatting.
#
# 2. **Interact with the LLM using the template**
#
#    This function handles communication with the language model using the rendered prompt. It is currently tailored for the Groq API, though the structure may vary if you use a different API.
#
# 3. **Save the LLM response to a JSON file**
#
#    To maintain a record of the process, we save the model's response along with metadata, including the model used, the prompt sent, and the annotated output (in XML format with entity annotations).

# %%
def load_and_render_prompt(template_path: str, text_to_annotate: str) -> str:
    """
    Load a Jinja2 template from a file and render it with the provided text to annotate.
    
    Args:
        template_path (str): Path to the template file.
        text_to_annotate (str): Text to be annotated.
    
    Returns:
        str: Rendered prompt string.
    """
    with open(template_path, "r") as f:
        template_content = f.read()
    template = jinja2.Template(template_content)
    return template.render(text_to_annotate=text_to_annotate)


def chat_with_template(prompt:str, template_path: str, model:str, text_to_annotate:str) -> str:
    """
    Chat with the Groq API using a template and a model.
    Args:
        template_path (str): Path to the template file.
        prompt (str): Rendered prompt.
        model (str): Model to use for the chat.
        text_to_annotate (str): Text to be annotated.
    Returns:
        str: Response from the chat completion.
    """
    delay = 1          # seconds
    max_retries = 5

    prompt = load_and_render_prompt(template_path, text_to_annotate)

    for attempt in range(max_retries + 1):
        try:
            chat_completion = client.chat.completions.create(
                messages=[{"role": "user", "content": prompt}],
                model=model,
            )
            return chat_completion.choices[0].message.content
        except InternalServerError as err:
            if getattr(err, "status_code", None) == 503 and attempt < max_retries:
                time.sleep(delay)
                delay *= 2          # exponential back-off
                continue
            raise  # non-503 or out of retries


def save_response_as_json(response_text:str, output_path:str) -> None:
    """
    Takes the response text from the AI and saves it as a JSON file.
    Args:
        response_text (str): The response text to save.
        output_path (str): Path to the output JSON file.
    """
    response_text
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(response_text, f, ensure_ascii=False, indent=2)

# %% [markdown]
# Before we start running annotations, we need to set up a directory structure to organize the outputs based on prompt types and models used.
#
# The following code will:
# - Create a root folder to store all LLM annotations.
#
#
# - For each prompt template in `LIST_PROMPTS`, create a subfolder.
#
#
# - Within each prompt folder, create additional subfolders for each model in `LIST_MODELS`.

# %%
# Get the current date and time
date_and_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

if API_TYPE == "groq":
    LIST_MODELS = LIST_MODELS_GROQ
elif API_TYPE == "openai":
    LIST_MODELS = LIST_MODELS_OPENAI
else:
    raise ValueError("Invalid API type. Choose 'openai' or 'groq'.")

# Make repository for LLM annotations
ouput_llm_annotation_folder = f"../llm_outputs/annotations_{date_and_time}/"
if not os.path.exists(ouput_llm_annotation_folder):
    os.makedirs(ouput_llm_annotation_folder)

# Make a folder for annotation stats
ouput_llm_stats_folder = f"../llm_outputs/stats_{date_and_time}/"
if not os.path.exists(ouput_llm_stats_folder):
    os.makedirs(ouput_llm_stats_folder)

# Create folder for each prompt type
# Then within that, create a folder for each model
for prompt in LIST_PROMPTS:
    prompt_name = os.path.basename(prompt)
    output_prompt_folder = os.path.join(ouput_llm_annotation_folder, prompt_name)
    if not os.path.exists(output_prompt_folder):
        os.makedirs(output_prompt_folder)

    for model in LIST_MODELS:
        output_model_folder = os.path.join(output_prompt_folder, model)
        if not os.path.exists(output_model_folder):
            os.makedirs(output_model_folder)

# %% [markdown]
# ## **Run LLM annotations**
# ---
#
# We will now test our LLM annotation pipeline on a subset of input texts. Specifically, we will:
#
# - Select the first 10 input files from the annotations folder.
#
#     - For each file, we will apply:
#
#         - Each prompt template in `LIST_PROMPTS`
#
#         - Each language model in `LIST_MODELS`
#
#     - Save the LLM's annotated response as a JSON file in a their designated directory: `../output_llm_annotations/{prompt_name}/{model}/{filename}`
#
#
#
# We can modify the amount of files that are annotated. To give an idea, for two models, three types of prompts, and 10 texts to annotate, this takes **~ 7mins**

# %%
# Use 10 input texts from the annotation folder
number_texts = 0

for filename in os.listdir(ANNOTATIONS_FOLDER): # Loop through the files in the annotations folder
    if number_texts >=NUMBER_OF_TEXTS_TO_ANNOTATE:
        break

    if filename.endswith(".json") and filename.count("_") == 1:
        number_texts += 1

        print(f"\nProcessing file {number_texts}: {filename} ==============")
        input_text, _ = process_json_file(os.path.join(ANNOTATIONS_FOLDER, filename))

        for prompt in LIST_PROMPTS: # Testing each type of prompt
            print(f"\nFile {number_texts} - Testing prompt: {prompt} -------\n")

            prompt_name = os.path.basename(prompt)
            output_prompt_folder = os.path.join(ouput_llm_annotation_folder, prompt_name)

            for model in LIST_MODELS: # Testing each model
                print(f"File {number_texts} - Testing model: {model}")

                output_model_folder = os.path.join(output_prompt_folder, model)

                response = chat_with_template(
                    prompt=prompt,
                    template_path=os.path.join(PROMPT_PATH, f"{prompt}.txt"),
                    model=model,
                    text_to_annotate=input_text
                )

                # Save the response as a JSON file
                output_path_for_json = os.path.join(output_prompt_folder, model, filename)
                data = {
                    "model": model,
                    "text_to_annotate": input_text,
                    "response": response
                }
                save_response_as_json(data, output_path_for_json)
# Out:
# Processing file 1: figshare_22213635.json ==============
#
# File 1 - Testing prompt: zero_shot -------
#
# File 1 - Testing model: gemma2-9b-it
# File 1 - Testing model: mistral-saba-24b
# File 1 - Testing model: llama-3.3-70b-versatile
# File 1 - Testing model: qwen-qwq-32b
# File 1 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 1 - Testing model: deepseek-r1-distill-llama-70b
#
# File 1 - Testing prompt: one_shot -------
#
# File 1 - Testing model: gemma2-9b-it
# File 1 - Testing model: mistral-saba-24b
# File 1 - Testing model: llama-3.3-70b-versatile
# File 1 - Testing model: qwen-qwq-32b
# File 1 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 1 - Testing model: deepseek-r1-distill-llama-70b
#
# File 1 - Testing prompt: few_shot -------
#
# File 1 - Testing model: gemma2-9b-it
# File 1 - Testing model: mistral-saba-24b
# File 1 - Testing model: llama-3.3-70b-versatile
# File 1 - Testing model: qwen-qwq-32b
# File 1 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 1 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 2: figshare_4757161.json ==============
#
# File 2 - Testing prompt: zero_shot -------
#
# File 2 - Testing model: gemma2-9b-it
# File 2 - Testing model: mistral-saba-24b
# File 2 - Testing model: llama-3.3-70b-versatile
# File 2 - Testing model: qwen-qwq-32b
# File 2 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 2 - Testing model: deepseek-r1-distill-llama-70b
#
# File 2 - Testing prompt: one_shot -------
#
# File 2 - Testing model: gemma2-9b-it
# File 2 - Testing model: mistral-saba-24b
# File 2 - Testing model: llama-3.3-70b-versatile
# File 2 - Testing model: qwen-qwq-32b
# File 2 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 2 - Testing model: deepseek-r1-distill-llama-70b
#
# File 2 - Testing prompt: few_shot -------
#
# File 2 - Testing model: gemma2-9b-it
# File 2 - Testing model: mistral-saba-24b
# File 2 - Testing model: llama-3.3-70b-versatile
# File 2 - Testing model: qwen-qwq-32b
# File 2 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 2 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 3: figshare_21263177.json ==============
#
# File 3 - Testing prompt: zero_shot -------
#
# File 3 - Testing model: gemma2-9b-it
# File 3 - Testing model: mistral-saba-24b
# File 3 - Testing model: llama-3.3-70b-versatile
# File 3 - Testing model: qwen-qwq-32b
# File 3 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 3 - Testing model: deepseek-r1-distill-llama-70b
#
# File 3 - Testing prompt: one_shot -------
#
# File 3 - Testing model: gemma2-9b-it
# File 3 - Testing model: mistral-saba-24b
# File 3 - Testing model: llama-3.3-70b-versatile
# File 3 - Testing model: qwen-qwq-32b
# File 3 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 3 - Testing model: deepseek-r1-distill-llama-70b
#
# File 3 - Testing prompt: few_shot -------
#
# File 3 - Testing model: gemma2-9b-it
# File 3 - Testing model: mistral-saba-24b
# File 3 - Testing model: llama-3.3-70b-versatile
# File 3 - Testing model: qwen-qwq-32b
# File 3 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 3 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 4: zenodo_6582985.json ==============
#
# File 4 - Testing prompt: zero_shot -------
#
# File 4 - Testing model: gemma2-9b-it
# File 4 - Testing model: mistral-saba-24b
# File 4 - Testing model: llama-3.3-70b-versatile
# File 4 - Testing model: qwen-qwq-32b
# File 4 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 4 - Testing model: deepseek-r1-distill-llama-70b
#
# File 4 - Testing prompt: one_shot -------
#
# File 4 - Testing model: gemma2-9b-it
# File 4 - Testing model: mistral-saba-24b
# File 4 - Testing model: llama-3.3-70b-versatile
# File 4 - Testing model: qwen-qwq-32b
# File 4 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 4 - Testing model: deepseek-r1-distill-llama-70b
#
# File 4 - Testing prompt: few_shot -------
#
# File 4 - Testing model: gemma2-9b-it
# File 4 - Testing model: mistral-saba-24b
# File 4 - Testing model: llama-3.3-70b-versatile
# File 4 - Testing model: qwen-qwq-32b
# File 4 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 4 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 5: zenodo_6478270.json ==============
#
# File 5 - Testing prompt: zero_shot -------
#
# File 5 - Testing model: gemma2-9b-it
# File 5 - Testing model: mistral-saba-24b
# File 5 - Testing model: llama-3.3-70b-versatile
# File 5 - Testing model: qwen-qwq-32b
# File 5 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 5 - Testing model: deepseek-r1-distill-llama-70b
#
# File 5 - Testing prompt: one_shot -------
#
# File 5 - Testing model: gemma2-9b-it
# File 5 - Testing model: mistral-saba-24b
# File 5 - Testing model: llama-3.3-70b-versatile
# File 5 - Testing model: qwen-qwq-32b
# File 5 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 5 - Testing model: deepseek-r1-distill-llama-70b
#
# File 5 - Testing prompt: few_shot -------
#
# File 5 - Testing model: gemma2-9b-it
# File 5 - Testing model: mistral-saba-24b
# File 5 - Testing model: llama-3.3-70b-versatile
# File 5 - Testing model: qwen-qwq-32b
# File 5 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 5 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 6: figshare_7783568.json ==============
#
# File 6 - Testing prompt: zero_shot -------
#
# File 6 - Testing model: gemma2-9b-it
# File 6 - Testing model: mistral-saba-24b
# File 6 - Testing model: llama-3.3-70b-versatile
# File 6 - Testing model: qwen-qwq-32b
# File 6 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 6 - Testing model: deepseek-r1-distill-llama-70b
#
# File 6 - Testing prompt: one_shot -------
#
# File 6 - Testing model: gemma2-9b-it
# File 6 - Testing model: mistral-saba-24b
# File 6 - Testing model: llama-3.3-70b-versatile
# File 6 - Testing model: qwen-qwq-32b
# File 6 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 6 - Testing model: deepseek-r1-distill-llama-70b
#
# File 6 - Testing prompt: few_shot -------
#
# File 6 - Testing model: gemma2-9b-it
# File 6 - Testing model: mistral-saba-24b
# File 6 - Testing model: llama-3.3-70b-versatile
# File 6 - Testing model: qwen-qwq-32b
# File 6 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 6 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 7: figshare_20300547.json ==============
#
# File 7 - Testing prompt: zero_shot -------
#
# File 7 - Testing model: gemma2-9b-it
# File 7 - Testing model: mistral-saba-24b
# File 7 - Testing model: llama-3.3-70b-versatile
# File 7 - Testing model: qwen-qwq-32b
# File 7 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 7 - Testing model: deepseek-r1-distill-llama-70b
#
# File 7 - Testing prompt: one_shot -------
#
# File 7 - Testing model: gemma2-9b-it
# File 7 - Testing model: mistral-saba-24b
# File 7 - Testing model: llama-3.3-70b-versatile
# File 7 - Testing model: qwen-qwq-32b
# File 7 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 7 - Testing model: deepseek-r1-distill-llama-70b
#
# File 7 - Testing prompt: few_shot -------
#
# File 7 - Testing model: gemma2-9b-it
# File 7 - Testing model: mistral-saba-24b
# File 7 - Testing model: llama-3.3-70b-versatile
# File 7 - Testing model: qwen-qwq-32b
# File 7 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 7 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 8: zenodo_4805388.json ==============
#
# File 8 - Testing prompt: zero_shot -------
#
# File 8 - Testing model: gemma2-9b-it
# File 8 - Testing model: mistral-saba-24b
# File 8 - Testing model: llama-3.3-70b-versatile
# File 8 - Testing model: qwen-qwq-32b
# File 8 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 8 - Testing model: deepseek-r1-distill-llama-70b
#
# File 8 - Testing prompt: one_shot -------
#
# File 8 - Testing model: gemma2-9b-it
# File 8 - Testing model: mistral-saba-24b
# File 8 - Testing model: llama-3.3-70b-versatile
# File 8 - Testing model: qwen-qwq-32b
# File 8 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 8 - Testing model: deepseek-r1-distill-llama-70b
#
# File 8 - Testing prompt: few_shot -------
#
# File 8 - Testing model: gemma2-9b-it
# File 8 - Testing model: mistral-saba-24b
# File 8 - Testing model: llama-3.3-70b-versatile
# File 8 - Testing model: qwen-qwq-32b
# File 8 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# File 8 - Testing model: deepseek-r1-distill-llama-70b
#
# Processing file 9: zenodo_51754.json ==============
#
# File 9 - Testing prompt: zero_shot -------
#
# File 9 - Testing model: gemma2-9b-it
# File 9 - Testing model: mistral-saba-24b
# File 9 - Testing model: llama-3.3-70b-versatile
# File 9 - Testing model: qwen-qwq-32b
# File 9 - Testing model: meta-llama/llama-4-maverick-17b-128e-instruct
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[8], line 25
#      21 print(f"File {number_texts} - Testing model: {model}")
#      23 output_model_folder = os.path.join(output_prompt_folder, model)
# ---> 25 response = chat_with_template(
#      26     prompt=prompt,
#      27     template_path=os.path.join(PROMPT_PATH, f"{prompt}.txt"),
#      28     model=model,
#      29     text_to_annotate=input_text
#      30 )
#      32 # Save the response as a JSON file
#      33 output_path_for_json = os.path.join(output_prompt_folder, model, filename)
#
# Cell In[6], line 32, in chat_with_template(prompt, template_path, model, text_to_annotate)
#      19 """
#      20 Chat with the Groq API using a template and a model.
#      21 Args:
#    (...)
#      27     str: Response from the chat completion.
#      28 """
#      30 prompt = load_and_render_prompt(template_path, text_to_annotate)
# ---> 32 chat_completion = client.chat.completions.create(
#      33     messages=[{"role": "user", "content": prompt}],
#      34     model=model,
#      35 )
#      36 return chat_completion.choices[0].message.content
#
# File ~/mdner/.venv/lib/python3.11/site-packages/groq/resources/chat/completions.py:322, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, reasoning_format, response_format, seed, service_tier, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     166 def create(
#     167     self,
#     168     *,
#    (...)
#     198     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     199 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     200     """
#     201     Creates a model response for the given chat conversation.
#     202
#    (...)
#     320       timeout: Override the client-level default timeout for this request, in seconds
#     321     """
# --> 322     return self._post(
#     323         "/openai/v1/chat/completions",
#     324         body=maybe_transform(
#     325             {
#     326                 "messages": messages,
#     327                 "model": model,
#     328                 "frequency_penalty": frequency_penalty,
#     329                 "function_call": function_call,
#     330                 "functions": functions,
#     331                 "logit_bias": logit_bias,
#     332                 "logprobs": logprobs,
#     333                 "max_completion_tokens": max_completion_tokens,
#     334                 "max_tokens": max_tokens,
#     335                 "n": n,
#     336                 "parallel_tool_calls": parallel_tool_calls,
#     337                 "presence_penalty": presence_penalty,
#     338                 "reasoning_format": reasoning_format,
#     339                 "response_format": response_format,
#     340                 "seed": seed,
#     341                 "service_tier": service_tier,
#     342                 "stop": stop,
#     343                 "stream": stream,
#     344                 "temperature": temperature,
#     345                 "tool_choice": tool_choice,
#     346                 "tools": tools,
#     347                 "top_logprobs": top_logprobs,
#     348                 "top_p": top_p,
#     349                 "user": user,
#     350             },
#     351             completion_create_params.CompletionCreateParams,
#     352         ),
#     353         options=make_request_options(
#     354             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     355         ),
#     356         cast_to=ChatCompletion,
#     357         stream=stream or False,
#     358         stream_cls=Stream[ChatCompletionChunk],
#     359     )
#
# File ~/mdner/.venv/lib/python3.11/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/mdner/.venv/lib/python3.11/site-packages/groq/_base_client.py:917, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 else:
#     915     retries_taken = 0
# --> 917 return self._request(
#     918     cast_to=cast_to,
#     919     options=options,
#     920     stream=stream,
#     921     stream_cls=stream_cls,
#     922     retries_taken=retries_taken,
#     923 )
#
# File ~/mdner/.venv/lib/python3.11/site-packages/groq/_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1003 if remaining_retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         input_options,
#    1007         cast_to,
#    1008         retries_taken=retries_taken,
#    1009         response_headers=err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File ~/mdner/.venv/lib/python3.11/site-packages/groq/_base_client.py:1054, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1050 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1051 # different thread if necessary.
#    1052 time.sleep(timeout)
# -> 1054 return self._request(
#    1055     options=options,
#    1056     cast_to=cast_to,
#    1057     retries_taken=retries_taken + 1,
#    1058     stream=stream,
#    1059     stream_cls=stream_cls,
#    1060 )
#
# File ~/mdner/.venv/lib/python3.11/site-packages/groq/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1028     retries_taken=retries_taken,
#    1029 )
#
# InternalServerError: Error code: 503 - {'error': {'message': 'Service Unavailable', 'type': 'internal_server_error'}}
